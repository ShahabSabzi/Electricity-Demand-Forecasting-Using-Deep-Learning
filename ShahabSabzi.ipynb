# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahabSabzi/Electricity-Demand-Forecasting-Using-Deep-Learning/blob/main/ShahabSabzi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime as dt
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from  scipy.stats import skew, kurtosis, shapiro

# %% [markdown]
# #Data of Hungary electricity demand for Jan. 2015 to Oct. 2021

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dda993a7-0c5b-4f4f-80ea-fe6bd29a11a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dda993a7-0c5b-4f4f-80ea-fe6bd29a11a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2015-2020.csv to 2015-2020.csv

# %%
data_15 = pd.read_csv('2015.csv')
data_16 = pd.read_csv('2016.csv')
data_17 = pd.read_csv('2017.csv')
data_18 = pd.read_csv('2018.csv')
data_19 = pd.read_csv('2019.csv')
data_20 = pd.read_csv('2020.csv')
data_21 = pd.read_csv('2021.csv')

# %%
print (data_15[:5])

data_15[:30*24*4].plot(title="2015 Energy Demand")
plt.ylabel("MWh")
plt.show()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2015 00:00 - 01.01.2015 00:15                  4363.0
# 1  01.01.2015 00:15 - 01.01.2015 00:30                  4304.0
# 2  01.01.2015 00:30 - 01.01.2015 00:45                  4239.0
# 3  01.01.2015 00:45 - 01.01.2015 01:00                  4178.0
# 4  01.01.2015 01:00 - 01.01.2015 01:15                  4165.0

# %%
print (data_16[:5])
data_16[:30*24*4].plot(title="2016 Energy Demand")
plt.ylabel("MWh")
plt.show()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2016 00:00 - 01.01.2016 00:15                  4274.0
# 1  01.01.2016 00:15 - 01.01.2016 00:30                  4206.0
# 2  01.01.2016 00:30 - 01.01.2016 00:45                  4134.0
# 3  01.01.2016 00:45 - 01.01.2016 01:00                  4083.0
# 4  01.01.2016 01:00 - 01.01.2016 01:15                  4071.0

# %%
print (data_17[:5])
data_17[:30*24*4].plot(title="2017 Energy Demand")
plt.ylabel("MWh")
plt.show()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2017 00:00 - 01.01.2017 00:15                  4197.0
# 1  01.01.2017 00:15 - 01.01.2017 00:30                  4176.0
# 2  01.01.2017 00:30 - 01.01.2017 00:45                  4121.0
# 3  01.01.2017 00:45 - 01.01.2017 01:00                  4106.0
# 4  01.01.2017 01:00 - 01.01.2017 01:15                  4113.0

# %%
print (data_18[:5])
data_18.plot(title="2018 Energy Demand")
plt.ylabel("MWh")
plt.show()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2018 00:00 - 01.01.2018 00:15                  4029.0
# 1  01.01.2018 00:15 - 01.01.2018 00:30                  4002.0
# 2  01.01.2018 00:30 - 01.01.2018 00:45                  3966.0
# 3  01.01.2018 00:45 - 01.01.2018 01:00                  3945.0
# 4  01.01.2018 01:00 - 01.01.2018 01:15                  3955.0

# %%
print (data_19[:5])
data_19.plot(title="2019 Energy Demand")
plt.ylabel("MWh")
plt.show()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2019 00:00 - 01.01.2019 00:15                  4117.0
# 1  01.01.2019 00:15 - 01.01.2019 00:30                  4096.0
# 2  01.01.2019 00:30 - 01.01.2019 00:45                  4065.0
# 3  01.01.2019 00:45 - 01.01.2019 01:00                  4050.0
# 4  01.01.2019 01:00 - 01.01.2019 01:15                  4060.0

# %%
print (data_20 [:5])
data_20.plot(title="2020 Energy Demand")
plt.ylabel("MWh")
plt.show()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2020 00:00 - 01.01.2020 00:15                  4374.0
# 1  01.01.2020 00:15 - 01.01.2020 00:30                  4324.0
# 2  01.01.2020 00:30 - 01.01.2020 00:45                  4284.0
# 3  01.01.2020 00:45 - 01.01.2020 01:00                  4220.0
# 4  01.01.2020 01:00 - 01.01.2020 01:15                  4173.0

# %%
df = pd.read_csv('2015-2020.csv')

# %%
df.plot(title="2020 Energy Demand")
plt.ylabel("MWh")
plt.show()

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210456 entries, 0 to 210455
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Time (CET)              210456 non-null  object
#  1   Actual Total Load [MW]  210409 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 3.2+ MB
