# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahabSabzi/Electricity-Demand-Forecasting-Using-Deep-Learning/blob/main/Shahab_Sabzi__Milestone2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
py.init_notebook_mode(connected=True)
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from matplotlib import pyplot
from math import sqrt
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import LSTM
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#this function is used to plot figs in plotly

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
            },
          });
        </script>
        '''))

# %%
data_2020 = pd.read_csv('drive/MyDrive/Colab Notebooks/data/2020.csv')

# %%
data_2020.head()
# Out:
#                             Time (CET)  Actual Total Load [MW]
# 0  01.01.2020 00:00 - 01.01.2020 00:15                    4374
# 1  01.01.2020 00:15 - 01.01.2020 00:30                    4324
# 2  01.01.2020 00:30 - 01.01.2020 00:45                    4284
# 3  01.01.2020 00:45 - 01.01.2020 01:00                    4220
# 4  01.01.2020 01:00 - 01.01.2020 01:15                    4173

# %%
data_2020.tail()
# Out:
#                                 Time (CET)  Actual Total Load [MW]
# 35135  31.12.2020 22:45 - 31.12.2020 23:00                    4441
# 35136  31.12.2020 23:00 - 31.12.2020 23:15                    4415
# 35137  31.12.2020 23:15 - 31.12.2020 23:30                    4358
# 35138  31.12.2020 23:30 - 31.12.2020 23:45                    4378
# 35139  31.12.2020 23:45 - 01.01.2021 00:00                    4356

# %%
print ("Some info about 2015 demand data")
data_2020.plot(title="Hungary 2020 Energy Demand")
plt.ylabel("MWh")
plt.show()
data_2020.describe()
# Out:
# Some info about 2015 demand data
#        Actual Total Load [MW]
# count            35140.000000
# mean              4884.528002
# std                779.227408
# min               2998.000000
# 25%               4307.000000
# 50%               4859.000000
# 75%               5432.000000
# max               6820.000000

# %%
data_2020 = data_2020.reset_index()
data_2020 = data_2020.drop(columns = "index", axis = 1)

# %%
# Removing duplicates
data_2020 = data_2020.drop_duplicates(subset="Time (CET)")

# %%
data_2020 = data_2020.drop(columns = "Time (CET)", axis = 1) #remove Time column in data and replacing with meaningful datetime

# %%
data_2020['datetime'] = pd.date_range(start='01-01-2020t00:00', periods=len(data_2020), freq="15min")  #specifying datetime
data_2020 = data_2020[['datetime', 'Actual Total Load [MW]']]

# %%
data_2020 = data_2020.set_index('datetime')

# %%
data_2020.head()
# Out:
#                      Actual Total Load [MW]
# datetime
# 2020-01-01 00:00:00                    4374
# 2020-01-01 00:15:00                    4324
# 2020-01-01 00:30:00                    4284
# 2020-01-01 00:45:00                    4220
# 2020-01-01 01:00:00                    4173

# %%
data_2020.tail()
# Out:
#                      Actual Total Load [MW]
# datetime
# 2020-12-31 22:45:00                    4441
# 2020-12-31 23:00:00                    4415
# 2020-12-31 23:15:00                    4358
# 2020-12-31 23:30:00                    4378
# 2020-12-31 23:45:00                    4356

# %% [markdown]
# Perfect data without missing values

# %%
# converting the data from 15 min periods into 1 hour periods
hourly_2020 = data_2020.iloc[0::4, :] # keeping every 4 sample starting from 0

# %%
hourly_2020.head(5)
# Out:
#                      Actual Total Load [MW]
# datetime
# 2020-01-01 00:00:00                    4374
# 2020-01-01 01:00:00                    4173
# 2020-01-01 02:00:00                    3896
# 2020-01-01 03:00:00                    3671
# 2020-01-01 04:00:00                    3552

# %%
# I want three last months of 2020 for this project
forth_quarter= hourly_2020.loc['10/1/2020  12:00:00 AM':'1/1/2021  12:00:00 AM']

# %%
#plotting three last months
configure_plotly_browser_state()
dc = go.Scatter(x=forth_quarter.index, y=forth_quarter, name= 'Demand last three months of 2020')
py.iplot([dc])

#to see this figure you need to open in colab
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id
", "2020-10-05T09:00:00", "2020-10-05T10:00:00", "2020-10-05T11:00:00", "2020-10-05T12:00:00", "2020-10-05T13:00:00", "2020-10-05T14:00:00", "2020-10-05T15:00:00", "2020-10-05T16:00:00", "2020-10-05T17:00:00", "2020-10-05T18:00:00", "2020-10-05T19:00:00", "2020-10-05T20:00:00", "2020-10-05T21:00:00", "2020-10-05T22:00:00", "2020-10-05T23:00:00", "2020-10-06T00:00:00", "2020-10-06T01:00:00", "2020-10-06T02:00:00", "2020-10-06T03:00:00", "2020-10-06T04:00:00", "2020-10-06T05:00:00", "2020-10-06T06:00:00", "2020-10-06T07:00:00", "2020-10-06T08:00:00", "2020-10-06T09:00:00", "2020-10-06T10:00:00", "2020-10-06T11:00:00", "2020-10-06T12:00:00", "2020-10-06T13:00:00", "2020-10-06T14:00:00", "2020-10-06T15:00:00", "2020-10-06T16:00:00", "2020-10-06T17:00:00", "2020-10-06T18:00:00", "2020-10-06T19:00:00", "2020-10-06T20:00:00", "2020-10-06T21:00:00", "2020-10-06T22:00:00", "2020-10-06T23:00:00", "2020-10-07T00:00:00", "2020-10-07T01:00:00", "2020-10-07T02:00:00", "2020-10-07T03:00:00", "2020-10-07T04:00:00", "2020-10-07T05:00:00", "2020-10-07T06:00:00", "2020-10-07T07:00:00", "2020-10-07T08:00:00", "2020-10-07T09:00:00", "2020-10-07T10:00:00", "2020-10-07T11:00:00", "2020-10-07T12:00:00", "2020-10-07T13:00:00", "2020-10-07T14:00:00", "2020-10-07T15:00:00", "2020-10-07T16:00:00", "2020-10-07T17:00:00", "2020-10-07T18:00:00", "2020-10-07T19:00:00", "2020-10-07T20:00:00", "2020-10-07T21:00:00", "2020-10-07T22:00:00", "2020-10-07T23:00:00", "2020-10-08T00:00:00", "2020-10-08T01:00: ...

# %%
plt.figure(figsize=(12,8))
plt.plot(forth_quarter, color='g', label='target')
plt.legend()
plt.show()

# %%
data = forth_quarter

# %%
#Use MinMaxScaler to normalize data to range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
values = data.values.reshape(-1,1)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(values)

# %%
data.max(), data.min(), data.mean()
# Out:
# (1.0, 0.0, 0.5597192)

# %%
data.shape[0]
# Out:
# 2208

# %%
# (batch, seq_length=60, features=1)
def make_timeseries_instances(data, seq_length=60):
  # to be done
  X = []
  Y = []
  for start in range(0, data.shape[0]-seq_length):
    X.append(data[start:start+seq_length])
    Y.append(data[start+seq_length])
  X = np.array(X)
  Y = np.array(Y)
  return X, Y

# %%
seq_length=60 
X,Y = make_timeseries_instances(data, seq_length=seq_length)
#X = X.reshape(960,40,-1)
#X = np.expand_dims(X,-1)
X = np.atleast_3d(X)
Y = np.expand_dims(Y, axis=-1)
print(X.shape)
print(Y.shape)
# Out:
# (2148, 60, 1)
# (2148, 1, 1)

# %%
plt.plot(data.reshape(-1)[500:700])

# %%
model = Sequential()
model.add(LSTM(16, input_shape=(seq_length, 1)))
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                1152
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', 
                   patience=50, verbose=1,
                   restore_best_weights=True)

history = model.fit(X,Y, batch_size=32, validation_split=0.2, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 4s 33ms/step - loss: 0.1266 - mae: 0.2885 - val_loss: 0.0364 - val_mae: 0.1620
# Epoch 2/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0343 - mae: 0.1609 - val_loss: 0.0351 - val_mae: 0.1563
# Epoch 3/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0319 - mae: 0.1545 - val_loss: 0.0334 - val_mae: 0.1510
# Epoch 4/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0295 - mae: 0.1486 - val_loss: 0.0306 - val_mae: 0.1449
# Epoch 5/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0271 - mae: 0.1420 - val_loss: 0.0268 - val_mae: 0.1381
# Epoch 6/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0251 - mae: 0.1367 - val_loss: 0.0246 - val_mae: 0.1311
# Epoch 7/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0223 - mae: 0.1284 - val_loss: 0.0224 - val_mae: 0.1235
# Epoch 8/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0197 - mae: 0.1200 - val_loss: 0.0191 - val_mae: 0.1136
# Epoch 9/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0162 - mae: 0.1080 - val_loss: 0.0158 - val_mae: 0.1019
# Epoch 10/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0129 - mae: 0.0940 - val_loss: 0.0112 - val_mae: 0.0853
# Epoch 11/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0099 - mae: 0.0802 - val_loss: 0.0100 - val_mae: 0.0793
# Epoch 12/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0085 - mae: 0.0747 - val_loss: 0.0085 - val_mae: 0.0736
# Epoch 13/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0075 - mae: 0.0703 - val_loss: 0.0060 - val_mae: 0.0609
# Epoch 14/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0066 - mae: 0.0659 - val_loss: 0.0046 - val_mae: 0.0528
# Epoch 15/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0059 - mae: 0.0615 - val_loss: 0.0038 - val_mae: 0.0476
# Epoch 16/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0050 - mae: 0.0557 - val_loss: 0.0031 - val_mae: 0.0427
# Epoch 17/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0041 - mae: 0.0492 - val_loss: 0.0031 - val_mae: 0.0430
# Epoch 18/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0034 - mae: 0.0449 - val_loss: 0.0022 - val_mae: 0.0370
# Epoch 19/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0031 - mae: 0.0423 - val_loss: 0.0020 - val_mae: 0.0353
# Epoch 20/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0030 - mae: 0.0424 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 21/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0023 - val_mae: 0.0360
# Epoch 22/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0026 - mae: 0.0388 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 23/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0025 - mae: 0.0380 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 24/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0024 - mae: 0.0368 - val_loss: 0.0022 - val_mae: 0.0358
# Epoch 25/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0022 - mae: 0.0359 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 26/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0022 - mae: 0.0348 - val_loss: 0.0022 - val_mae: 0.0351
# Epoch 27/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0021 - mae: 0.0349 - val_loss: 0.0027 - val_mae: 0.0403
# Epoch 28/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0022 - mae: 0.0360 - val_loss: 0.0019 - val_mae: 0.0328
# Epoch 29/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0020 - mae: 0.0334 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 30/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0020 - mae: 0.0334 - val_loss: 0.0018 - val_mae: 0.0320
# Epoch 31/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 0.0017 - val_mae: 0.0312
# Epoch 32/50
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 0.0016 - val_mae: 0.0307
# Epoch 33/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 34/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0018 - mae: 0.0317 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 35/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0017 - mae: 0.0311 - val_loss: 0.0019 - val_mae: 0.0333
# Epoch 36/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0017 - mae: 0.0311 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 37/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0017 - mae: 0.0307 - val_loss: 0.0017 - val_mae: 0.0322
# Epoch 38/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0017 - mae: 0.0309 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 39/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 40/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0017 - mae: 0.0306 - val_loss: 0.0018 - val_mae: 0.0322
# Epoch 41/50
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0016 - mae: 0.0300 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 42/50
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0016 - mae: 0.0300 - val_loss: 0.0015 - val_mae: 0.0297
# Epoch 43/50
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0017 - val_mae: 0.0319
# Epoch 44/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0018 - val_mae: 0.0316
# Epoch 45/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0015 - mae: 0.0293 - val_loss: 0.0020 - val_mae: 0.0340
# Epoch 46/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0015 - mae: 0.0287 - val_loss: 0.0017 - val_mae: 0.0322
# Epoch 47/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0015 - mae: 0.0296 - val_loss: 0.0016 - val_mae: 0.0310
# Epoch 48/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0014 - mae: 0.0277 - val_loss: 0.0017 - val_mae: 0.0308
# Epoch 49/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0014 - mae: 0.0283 - val_loss: 0.0017 - val_mae: 0.0311
# Epoch 50/50
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0016 - val_mae: 0.0299

# %%
#Plot line graph to show amount loss according the the epoch
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
preds = model.predict(X)

# %%
Y.shape , preds.shape
# Out:
# ((2148, 1, 1), (2148, 1))

# %%
Y = Y.reshape(2148,1)

# %%
#Scaler Inverse Y back to normal value
preds_inv = scaler.inverse_transform(preds.reshape(-1, 1))
Y_inv = scaler.inverse_transform(Y.reshape(-1, 1))

# %%
#Convert X to dates¶
predictDates = forth_quarter.tail(len(preds_inv)).index

# %%
Y_reshape = Y_inv.reshape(len(Y_inv))
pred_reshape = preds_inv.reshape(len(preds_inv))

# %%
configure_plotly_browser_state()
actual_chart = go.Scatter(x=predictDates, y=Y_reshape, name= 'Actual Load')
predict_chart = go.Scatter(x=predictDates, y=pred_reshape, name= 'Predicted Load')
py.iplot([actual_chart, predict_chart])

#to see this figure you need to open in colab
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="ec977857-ec6c-4e3e-9b93-13a1b09de433" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ec977857-ec6c-4e3e-9b93-13a1b09de433")) {
#                     Plotly.newPlot(
#                         'ec977857-ec6c-4e3e-9b93-13a1b09de433',
#                         [{"name": "Actual Load", "type": "scatter", "x": ["2020-10-03T12:00:00", "2020-10-03T13:00:00", "2020-10-03T14:00:00", "2020-10-03T15:00:00", "2020-10-03T16:00:00", "2020-10-03T17:00:00", "2020-10-03T18:00:00", "2020-10-03T19:00:00", "2020-10-03T20:00:00", "2020-10-03T21:00:00", "2020-10-03T22:00:00", "2020-10-03T23:00:00", "2020-10-04T00:00:00", "2020-10-04T01:00:00", "2020-10-04T02:00:00", "2020-10-04T03:00:00", "2020-10-04T04:00:00", "2020-10-04T05:00:00", "2020-10-04T06:00:00", "2020-10-04T07:00:00", "2020-10-04T08:00:00", "2020-10-04T09:00:00", "2020-10-04T10:00:00", "2020-10-04T11:00:00", "2020-10-04T12:00:00", "2020-10-04T13:00:00", "2020-10-04T14:00:00", "2020-10-04T15:00:00", "2020-10-04T16:00:00", "2020-10-04T17:00:00", "2020-10-04T18:00:00", "2020-10-04T19:00:00", "2020-10-04T20:00:00", "2020-10-04T21:00:00", "2020-10-04T22:00:00", "2020-10-04T23:00:00", "2020-10-05T00:00:00", "2020-10-05T01:00:00", "2020-10-05T02:00:00", "2020-10-05T03:00:00", "2020-10-05T04:00:00", "2020-10-05T05:00:00", "2020-10-05T06:00:00", "2020-10-05T07:00:00", "2020-10-05T08:00:00", "2020-10-05T09:00:00", "2020-10-05T10:00:00", "2020-10-05T11:00:00", "2020-10-05T12:00:00", "2020-10-05T13:00:00", "2020-10-05T14:00:00", "2020-10-05T15:00:00", "2020-10-05T16:00:00", "2020-10-05T17:00:00", "2020-10-05T18:00:00", "2020-10-05T19:00:00", "2020-10-05T20:00:00", "2020-10-05T21:00:00", "2020-10-05T22:00:00", "2020-10-05T23:00:00", "2020-10-06T00:00:00", "2020-10-06T01:00:00", "2020-10-06T02:00: